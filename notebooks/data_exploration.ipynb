# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Getrude\Desktop\product-kpi-dashboard\Product-KPI-dashboard\data\product_data.csv")
df.head()
# Out:
#          date  new_users  active_users      revenue  churn_rate
# 0  2023-01-01         47           190  1239.314300    0.018688
# 1  2023-01-02         55           204   968.294085    0.031770
# 2  2023-01-03         42           205   994.539092    0.011116
# 3  2023-01-04         52           202   813.346408    0.052189
# 4  2023-01-05         58           212   911.343550    0.037114

# %%
df.shape
# Out:
# (365, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          365 non-null    object
#  1   new_users     365 non-null    int64
#  2   active_users  365 non-null    int64
#  3   revenue       365 non-null    float64
#  4   churn_rate    365 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 14.4+ KB

# %%
df.describe()
# Out:
#         new_users  active_users      revenue  churn_rate
# count  365.000000    365.000000   365.000000  365.000000
# mean    49.213699    200.189041  1024.398647    0.054286
# std      7.250110     15.163935   198.821882    0.025829
# min     29.000000    159.000000   415.729903    0.010141
# 25%     44.000000    189.000000   889.628371    0.034819
# 50%     49.000000    201.000000  1017.681377    0.053887
# 75%     54.000000    210.000000  1155.672215    0.075158
# max     69.000000    245.000000  1638.621514    0.099804

# %%
df.isnull().sum()
# Out:
# date            0
# new_users       0
# active_users    0
# revenue         0
# churn_rate      0
# dtype: int64

# %%
# Plot revenue trend
df.plot(x="date", y="revenue", figsize=(10,5), title="Daily Revenue")
plt.show()

# Plot active users trend
df.plot(x="date", y="active_users", figsize=(10,5), title="Daily Active Users")
plt.show()

# Plot churn distribution
df["churn_rate"].hist(bins=20)
plt.title("Churn Rate Distribution")
plt.show()
